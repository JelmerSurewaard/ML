# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
learning_objects = pd.read_csv('data.csv', sep=';')
plotting_objects = pd.read_csv('plot_objects.csv', index_col=0)

plotting_objects.head()
# Out:
#     id    x-coord    y-coord  cluster                         title  \
# 0  d.4 -75.875237  -1.409726       29        Emotional Intelligence
# 1  d.5  63.366180  17.435656        7     Stress Management Balance
# 2  d.6  65.117462  17.481592        7  Time Management Productivity
# 3  d.7   0.617048 -24.799524       11               Public Speaking
# 4  d.8 -56.131985 -34.599560        0    Virtual Team Communication
#
#                                               colors
# 0  (0.9955879496320674, 0.0, 0.9463241007358653, ...
# 1                (0.7955870308811486, 1.0, 0.0, 1.0)
# 2                (0.7955870308811486, 1.0, 0.0, 1.0)
# 3               (0.10073339485104227, 1.0, 0.0, 1.0)
# 4                               (1.0, 0.0, 0.0, 1.0)

# %%
scat = px.scatter(plotting_objects, x='x-coord', y='y-coord', color='colors', hover_data={
    'x-coord': False,
    'y-coord': False,
    'colors': False,
    'title': True
}, width=1000, height=1000)

scat.update_layout(showlegend=False)

scat
