# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df[df.columns.difference(['density', 'chlorides'])] = df[df.columns.difference(['density', 'chlorides'])].round(2)
df['density'] = df['density'].round(5)

df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
sns.histplot(data=df, x='residual sugar')
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Count'>

# %%
sns.histplot(data=df, x='alcohol')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(data=df, x='pH')
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Count'>

# %%
sns.histplot(data=df, x='quality')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Count'>

# %%
sns.lineplot(data=df, y='quality', x='alcohol')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %%
#df = df[df['volatile acidity'] < 1.05]
sns.lineplot(data=df, y='quality', x='volatile acidity')
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
temp = df[(df['quality'] == 4) | (df['quality'] == 5)]
sns.scatterplot(data=temp, x='alcohol', y='chlorides', hue='quality')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='chlorides'>

# %%
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
plt.figure(figsize = (28,10))
sns.heatmap(data=df.corr(), annot=True)
# Out:
# <AxesSubplot:>
