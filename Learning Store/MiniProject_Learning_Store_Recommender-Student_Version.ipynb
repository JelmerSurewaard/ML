# %% [markdown]
# # ML5 Mini Project - Learning Store Recommender

# %% [markdown]
# **The goal of this project is to leverage machine learning to make recommendations to Learning Store users.**
# Users are browsing anonymously the Learning Store. The recommender returns similar or related items as those they are being queried or viewed.
# The recommender uses unsupervised machine learning to identify and group similarities in sets of data.
# Deliverable is a content filtering recommender returning items related to watched topic and a visualization of the cluster (inc. dimensionality reduction) and a cluster object locator !

# %% [markdown]
# ## 1 - Import complete learning store database (6000+ Learning Objects)

# %%
import pandas as pd

# %%
# Load the csv into a data frame
df = pd.read_csv("course_061120.csv")
df.head(50)
# Out:
#                  ID                                              Title  \
# 0               d.4                             Emotional Intelligence
# 1               d.5                        Stress Management & Balance
# 2               d.6                     Time Management & Productivity
# 3               d.7                                    Public Speaking
# 4               d.8                         Virtual Team Communication
# 5               d.9                        Interpersonal Communication
# 6              d.13         Cross Cultural Awareness and Communication
# 7              d.17                               Software Engineering
# 8              d.33   Problem Solving and Decision Making Fundamentals
# 9              d.43                                    Web Programming
# 10             d.50                         General Project Management
# 11             d.51  Project Management Professional PMP® Certifica...
# 12             d.52                        Risk Management- self study
# 13             d.87                        Software Robustness Testing
# 14              p.6                                      Safari Online
# 15              p.7                                           Springer
# 16              p.9  Skillport - Skillsoft's Online Learning Portal...
# 17             p.11             Nokia Learning & Development Hub (LMS)
# 18              c.4                              For ION Staff Members
# 19              c.5                              For NSW Staff Members
# 20              c.6                               For FN Staff Members
# 21              c.7                               For MN Staff Members
# 22             c.12                                     Get Certified!
# 23             c.13                                Product Development
# 24             c.14                                 Project Management
# 25             c.15                              For NOP Staff Members
# 26             c.16                                  Processes & Tools
# 27             c.17                                 Telecom Technology
# 28             c.19                                  Sales & Marketing
# 29             c.21                                     Radio Networks
# 30             c.22                                     Fixed Networks
# 31             c.23                                     Nokia Software
# 32             c.24                              IP & Optical Networks
# 33             c.33                                         What's New
# 34             c.35                                 Online Nokia Books
# 35             c.36                         For Video BU staff members
# 36             c.37                                Business Consultant
# 37             c.39                                             Vision
# 38             c.57                                    LTE Debug Tools
# 39             c.58    Mobile Networks Care & Maintain Tools Blueprint
# 40  n.1455635019223  CEMT for Measure Owners / Project Team Members...
# 41  n.1455635261149                                 CEMT for Approvers
# 42  n.1455635719676                               CEMT for Controllers
# 43  n.1455638218110            Cost Efficiency Measurement Tool (CEMT)
# 44  n.1455703052874                   CEMT for System & Project Admins
# 45  n.1457003014038                                        Nokia VoLTE
# 46  n.1457003159282                          Nokia Liquid Applications
# 47  n.1457003511987                 LTE technology - Nokia LTE Starter
# 48  n.1457364353349                          1350 OMS product overview
# 49  n.1457364959720                                 SR-OS Fundamentals
#
#                                           Description  \
# 0   <p>Emotional intelligence is the skill at perc...
# 1   <p>This is a self-learning program for learnin...
# 2   <p>You'll learn strategies to better mangage y...
# 3   <p>In today’s business world, most of us need ...
# 4   <p><span style="color: rgb(78, 78, 78);">This ...
# 5   <p>Good interpersonal communication skills hel...
# 6   <p>It is a field of study that looks at how pe...
# 7   <p>The Software Engineering Community is a sel...
# 8   <p>In this community you will start by reviewi...
# 9   The Web Programming Community is a self-learni...
# 10  <p>In this curriculum learners will first opti...
# 11  <p>This curriculum comprises learning modules ...
# 12  <p>This curricula comprises Risk Management re...
# 13  <p>The Software Engineering Community is a sel...
# 14  Safari Books Online provides PC and mobile acc...
# 15  Springer e-books are a comprehensive online co...
# 16  <p><a href="https://nokia.sharepoint.com/sites...
# 17  <p>Nokia’s Nokia Learning &amp; Development Hu...
# 18  <p>Learning Solutions recommended for ION staf...
# 19  <p>This collection contains courses and materi...
# 20  <p>Learning solutions recommended for FN staff...
# 21  <p>PLAY+LEARN=<a href="https://nokia.sharepoin...
# 22                                                NaN
# 23  <p>This collection covers a range of content t...
# 24  <p><strong>Project Management learning includi...
# 25  <p><br></p><p>Welcome to this set of learning ...
# 26  <p>This collections contains a range of learni...
# 27                                                NaN
# 28  <p>Collection includes topics for sales &amp; ...
# 29                                                NaN
# 30  <p>This collection contains a wide range of Fi...
# 31                                                NaN
# 32                                                NaN
# 33  This collection shows the latest learning solu...
# 34  <p>A short selection of books from Nokia. You ...
# 35  Learning solutions recommended for the Video B...
# 36  The Business Consultant collection addresses n...
# 37  Le programme “Vision” a pour objectif le dével...
# 38            Learnning solutions on LTE debug tools.
# 39  Tools learning solutions recommended for Mobil...
# 40  <p>The course equips the user with all skills ...
# 41  <p>This course gives an introduction to CEMT w...
# 42  <p>This course focuses on the passive usage of...
# 43  <p>CEMT refers to Cost Efficiency Measurement ...
# 44  <p>This course focuses on all aspects of CEMT,...
# 45  <p>Nokia VoLTE training is designed for Nokia ...
# 46  <p>• Liquid Applications - Motivation and Bene...
# 47  <p>Nokia LTE starter provides an overview of t...
# 48  <p>This course aims to provide an overview of ...
# 49  <p>The SR-OS Fundamentals eLearning course des...
#
#                                            Objectives  \
# 0   <p>Here are the topics you will learn about by...
# 1   <p>At the end of this track you will be able t...
# 2   <p>At the end of this, you will be able to:</p...
# 3   <p>After studying the Public Speaking, you wil...
# 4   <p>Here are the topics you will learn about by...
# 5   <p>Here are the topics you will learn about by...
# 6   <p>Here are the topics you will learn about by...
# 7   <p>Taking this learning program will allow you...
# 8   <p>These are the topics you will learn about b...
# 9   Discover and learn how to develop web applicat...
# 10  <p>By taking the learning recommended in this ...
# 11  <p>By taking the learning recommended in this ...
# 12  <p>By taking the learning recommended in this ...
# 13  <ul><li>Get a comprehensive understanding of r...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  <p>- What are the responsibilities of your rol...
# 41  <ul><li>What are the responsibilities of appro...
# 42  <p>- What are the responsibilities of your rol...
# 43                                                NaN
# 44  <p>- What are responsibilities of your role</p...
# 45                                                NaN
# 46  <p>After the Nokia Liquid Application training...
# 47                                                NaN
# 48  <ul><li>Describe Telecommunication Management ...
# 49  <p>By the end of the course, participants will...
#
#                                             Solutions  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  ['d.16', 'n.1500643053715', 'd.33', 'c.32', 'c...
# 19  ['n.1576092570730', 'n.1526540993998', 'n.1531...
# 20  ['d.33', 'n.1457425837509', 'n.1480933299878',...
# 21  ['n.1510237146830', 'n.1510237095513', 'n.1510...
# 22  ['n.1558610058526', 'd.35', 'n.1467622682648',...
# 23  ['n.1540982430919', 'n.1540304371684', 'n.1540...
# 24  ['n.1583813579436', 'n.1489505010552', 'n.1490...
# 25  ['n.1568552729457', 'd.54', 'd.56', 'd.57', 'n...
# 26  ['n.1478871964266', 'n.1491758561779', 'n.1512...
# 27  ['n.1547630331213', 'd.35', 'n.1480513869443',...
# 28  ['n.1465578454389', 'n.1465243651681', 'n.1521...
# 29  ['n.1493877632058', 'n.1493878250776', 'n.1457...
# 30  ['n.1507815034295', 'n.1490006114779', 'n.1522...
# 31  ['d.35', 'n.1457428440191', 'n.1539961257296',...
# 32  ['n.1513177589141', 'n.1513172668132', 'n.1512...
# 33  ['n.1604511790519', 'n.1604511420367', 'n.1604...
# 34  ['n.1465495758228', 'n.1465491871963', 'n.1465...
# 35                                  ['d.102', 'c.37']
# 36               ['d.9', 'd.10', 'd.4', 'd.5', 'd.3']
# 37  ['c.46', 'n.1464253433129', 'n.1465997722945',...
# 38               ['d.134', 'd.138', 'd.137', 'd.136']
# 39     ['d.136', 'd.137', 'd.138', 'n.1470865599244']
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43  ['n.1455635719676', 'n.1455635019223', 'n.1455...
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                              Duration
# 0                            <p>2 hour 35 minutes</p>
# 1                                  <p>48 minutes.</p>
# 2                           <p>1 hour, 36 minutes</p>
# 3                              <p>4 hours, 30 min</p>
# 4                             <p>Maximum 5 hours.</p>
# 5                             <p>Maximum 4 hours.</p>
# 6                              <p>Maximum 4 hours</p>
# 7                                  <p>33:54 hours</p>
# 8                            <p>3 hour 52 minutes</p>
# 9   Up to 17 hours, depending on your level of exp...
# 10  <p>Maximum 7 hours, depending on your level of...
# 11                                    <p>40 hours</p>
# 12  <p>Maximum 10 hours, depending of your level o...
# 13                                 <p>09:25 hours</p>
# 14                                                NaN
# 15                                                NaN
# 16                          <p>Hours of learning!</p>
# 17                                         <p>N/A</p>
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                      <p>1 hour</p>
# 41                                  <p>40 minutes</p>
# 42                                  <p>20 minutes</p>
# 43                                                NaN
# 44                                  <p>55 minutes</p>
# 45  <p>Minimum 1.5 hours, Maximum 28 hours, depend...
# 46                                          1.5 hours
# 47  <p>Minimum 1 hour, Maximum 10 hours, depending...
# 48  <p>The recording lasts 40 minutes. The time ne...
# 49                                           12 hours

# %% [markdown]
# ## 2 - Return top 5 recommendation for a specific Learning Object (item) with confidence level > 0,3

# %% [markdown]
# ## 3 - Group all Learning Object in Clusters

# %% [markdown]
# ## 4 - Plot all Learning Object per cluster

# %% [markdown]
# ## 5 - Create a Learning Object Locator
# This function returns the graphical position of the learning Object plot in the galaxy of clusters

# %% [markdown]
# ## 6 - Zooming on Learning Object
# Region of the Learning Store can be crowded. Hence the use of this function to zoom in/out on the region. The zoom factor is passed as function parameter.
